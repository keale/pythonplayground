# %%
import tango
scoutds = tango.DeviceProxy("192.168.50.13:10000/lima/limaccd/1")

# %%
scoutds.State()
scoutds.acq_status
# Out:
# 'Running'

# %%
scoutds.get_attribute_list()
# Out:
# ['lima_version', 'lima_type', 'camera_type', 'camera_model', 'user_detector_name', 'user_instrument_name', 'camera_pixelsize', 'acq_status', 'acq_status_fault_error', 'acc_expo_time', 'acc_nb_frames', 'acc_dead_time', 'acc_live_time', 'acc_saturated_active', 'acc_saturated_threshold', 'acc_saturated_cblevel', 'acq_mode', 'acc_time_mode', 'acq_nb_frames', 'acq_expo_time', 'acc_max_expo_time', 'acc_mode', 'acc_threshold_before', 'acc_offset_before', 'acc_out_type', 'concat_nb_frames', 'latency_time', 'valid_ranges', 'acq_trigger_mode', 'image_roi', 'image_sizes', 'image_max_dim', 'image_type', 'image_width', 'image_height', 'image_bin', 'image_flip', 'image_rotation', 'last_image_acquired', 'last_base_image_ready', 'last_image_ready', 'last_image', 'last_image_saved', 'last_counter_ready', 'image_events_push_data', 'image_events_max_rate', 'ready_for_next_image', 'ready_for_next_acq', 'saving_directory', 'saving_prefix', 'saving_suffix', 'saving_next_number', 'saving_format', 'saving_m
# ...

# %%
scoutds.last_image
# Out:
# ('DATA_ARRAY',
# ...

# %%
scoutds.acq_trigger_mode="External_trigger_multi"
scoutds.acq_nb_frames=60

# %%
scoutds.stopAcq()

scoutds.prepareAcq()

# %%
scoutds.startAcq()
